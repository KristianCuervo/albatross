# %%
import numpy as np
import matplotlib.pyplot as plt

from src import Albatross, Factory, Ensemble

# --- Parameters ---
N     = [64]
V_ref = [10.0]
theta_warm = np.linspace(0, 0.999 * np.pi, 5, endpoint=True)
theta = np.linspace(0, 1 * np.pi, 60, endpoint=False)

# --- Run ---
bird    = Albatross.from_toml()
#warm_up = Factory(bird=bird, N=N, V_ref=V_ref, theta=theta_warm, n_procs=1).run()
factory = Factory(bird=bird, N=N, V_ref=V_ref, theta=theta, n_procs=8)
ens     = factory.run()
# Out:
# Optimising: theta = 0.41887902047863906, v_ref = 10.0Optimising: theta = 0.10471975511965977, v_ref = 10.0Optimising: theta = 0.0, v_ref = 10.0Optimising: theta = 0.3141592653589793, v_ref = 10.0
#
#
#
# Optimising: theta = 0.6283185307179586, v_ref = 10.0Optimising: theta = 0.20943951023931953, v_ref = 10.0Optimising: theta = 0.5235987755982988, v_ref = 10.0Optimising: theta = 0.7330382858376183, v_ref = 10.0
#
#
#
# Optimising: theta = 0.05235987755982988, v_ref = 10.0
# Optimising: theta = 0.47123889803846897, v_ref = 10.0
# Optimising: theta = 0.7853981633974483, v_ref = 10.0
# Optimising: theta = 0.6806784082777885, v_ref = 10.0
# Optimising: theta = 0.5759586531581287, v_ref = 10.0
# Optimising: theta = 0.8377580409572781, v_ref = 10.0
# Optimising: theta = 0.9424777960769379, v_ref = 10.0
# Optimising: theta = 1.0471975511965976, v_ref = 10.0
# Optimising: theta = 0.15707963267948966, v_ref = 10.0
# Optimising: theta = 0.2617993877991494, v_ref = 10.0
# ...

# %%
fig1, ax1 = ens.plot_ground_speed(save=True)
plt.show()

fig2, ax2 = ens.plot_cycle_times(save=True)
plt.show()

fig3, ax3 = ens.plot_vmg_polar(save=True)
ax3.set_title("Tacking polar velocities [m/s]")
plt.show()

# %%
ens.plot_3d_trajectories()
